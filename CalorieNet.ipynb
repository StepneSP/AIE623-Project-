# %% [markdown]
# <a href="https://colab.research.google.com/github/StepneSP/AIE623-Project-/blob/main/CalorieNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is **🍀CalorieNet** and What is **Nutrition5k** Dataset

# %% [markdown]
# **🍀CalorieNet** is a reimplementation of the **Nutrition5k** dataset and model, **designed to estimate the nutritional content of a dish** (calories, protein, fat, carbohydrates, and mass) from a single image.
#
# It combines multi-label ingredient classification with mass regression, leveraging a deep learning model built on an EfficientNet-B0 backbone.

# %% [markdown]
# The project uses a multi-task learning approach to:
#
# **Classify Ingredients**: Identify which ingredients are present in a dish image.
#
# **Predict Mass**: Estimate the total dish mass (in grams).
#
# **Calculate Nutrition**: Combine predictions with per-gram nutritional data to compute:
#
# *   Total Calories
# *   Protein
# *   Fat
# *   Carbohydrates

# %% [markdown]
# **Dish2Calories** modesl *which is the model used in this API* is trained on the **Nutrition5k** dataset, which includes:
#
# 5000 unique dishes, each with ~16 images from alternating angles.
#
# Directory structure: Images grouped by dish ID.
#
# Metadata: CSVs with nutritional info (calories, protein, fat, carbs, and mass).

# %% [markdown]
# # About The Code

# %% [markdown]
# **Google Colab Documantation**
#
# This collab documantation is essentially consists of the codes required to run the **🍀CalorieNet** app.
#
# Training of the model and .py files needed are in the attachment files.
#
# The nutrition5k database used for training purposes can also be reached through the google cloud link provided. [HERE NUTRITION5K DATABASE](https://console.cloud.google.com/storage/browser/nutrition5k_dataset)
#
# **Model Location and Usage**
#
# startup() funtion in inference.py, uses CalorieNet.from_checkpoint() method and installs the required data a.k.a. the model and weights. Which are in dataset_info.json and efficientnet_b0.pth respectfully.
#
# **Predictions**
#
# When the image is sent to the demo webpage, API server a.k.a. inference.py acts as a two way tunnel and gets the image to the /predict enpoint, in which the image is procesed by predictors.
#
# **App**
#
# **🍀CalorieNet** which is essentially just a streamlit app uses app.py for its configuration. App is just a user interface to send the images to inference.py and project the predictions.

# %% [markdown]
# To get the API server up and running inference.py files was ran and to keep it running in the background nohup command is chosen. This way even when the google colab enviroment is down the API server will keep working. And also both inference and streamlit commands will be able to run.

# %%
get_ipython().system('nohup python inference.py > fastapi_output.log 2>&1 &')

# %% [markdown]
# Since streamlit isn't in the base file architecture of google collab it has to be installed.

# %%
get_ipython().system('pip install streamlit')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 105.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 59.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Just like inference.py, to run app.py on streamlit indefinetly, nuhup command is needed.

# %%
get_ipython().system('nohup streamlit run app.py > streamlit_output.log 2>&1 &')

# %% [markdown]
# Since streamlit is a demo webpage system that runs of local files and IP to run it on google collab, a proxy like ngrok is needed.

# %%
get_ipython().system('pip install pyngrok')

# %% [markdown]
# And to use ngrok we need a authentication token is needed.

# %%
from pyngrok import ngrok
from google.colab import userdata

NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open a ngrok tunnel to the Streamlit port (8502)
streamlit_public_url = ngrok.connect(8502)
print(f"Streamlit Public URL: {streamlit_public_url}")
# Out:
# Streamlit Public URL: NgrokTunnel: "https://elsewhere-unrapacious-annika.ngrok-free.dev" -> "http://localhost:8502"

# %% [markdown]
# By the link provided as the outcome of this code we can access our streamlit app indefienetly. Though unlike normal streamlit apps we cannot customize our url or develop it as a streamlit app. To be able to do this we have to use a local enviroment and install all the requirements and run the app locally.
